# %%
pip install pytrends

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Business Analytics"])
data = trends.interest_by_region()
data=data.sort_values(by="Business Analytics", ascending=False)
data=data.head(10)
print(data)
# Out:
#                       Business Analytics
# geoName
# Singapore                            100
# China                                 77
# India                                 42
# St. Helena                            37
# Ghana                                 29
# Hong Kong                             29
# Nepal                                 27
# United Arab Emirates                  26
# Ireland                               26
# Australia                             24

# %%
data.reset_index().plot(x="geoName", y="Business Analytics",
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en=US',tz=360)
data.build_payload(kw_list=['Business Analytics'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20,15))
data['Business Analytics'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches done for Business Analytics',fontweight='bold')
plt.xlabel('year')
plt.ylabel('Total Count')
plt.show()
